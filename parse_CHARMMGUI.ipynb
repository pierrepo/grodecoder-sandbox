# %%
from bs4 import BeautifulSoup, Tag
import requests
import pandas as pd
from pathlib import Path

import MDAnalysis as mda
from collections import Counter
import os

# %% [markdown]
# # For https://www.charmm-gui.org/?doc=archive&lib=lipid

# %%
def parse_lipid_from_charmm_gui1() -> pd.core.frame.DataFrame:
    """Parses lipid information from the CHARMM-GUI website and saves it as a CSV file.

    Returns
    -------
        pd.core.frame.DataFrame
            A DataFrame containing the lipid information with columns:
                - "Name": The name of the lipid.
                - "Alias": The alias of the lipid extracted from the download link.
                - "Category": The category under which the lipid is listed.
                - "Link": The download link for the lipid file.
    """
    url = "https://www.charmm-gui.org/?doc=archive&lib=lipid"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    base_url = "https://www.charmm-gui.org"
    col_names = ["Name", "Alias", "Category", "Link"]
    recordings = []
        
    rows = soup.find_all('div', id='main')
    for row in rows:
        for div in row.find_all("div"):
            for title in div.find_all("b"):
                for ul in div.find_all("ul"):
                    for li in ul.find_all('li'):
                        sterol_name = li.find("span").get_text().split()[0]
                        
                        download_link = base_url + li.find("a", href=True)["href"]
                        alias = download_link.split("/")[-1]
                        alias = alias.split('.')[0]
                        
                        recording = {"Name": sterol_name, 
                                     "Alias": alias, 
                                     "Category": title.get_text().strip(),
                                     "Link": download_link }
                        recordings.append(recording)
        
    df = pd.DataFrame(recordings)
    df.to_csv('lipid_CHARMM_GUI1.csv', sep=';', index=False, header=True, columns=col_names)
    return df

# %%
lipid_list = parse_lipid_from_charmm_gui1()
lipid_list
# Out:
#              Name  Alias         Category  \
# 0     CHOLESTEROL   chl1          Sterols
# 1      ERGOSTEROL    erg          Sterols
# 2            DPOP   dpop          Sterols
# 3    β-SITOSTEROL   sito          Sterols
# 4    STIGMASTEROL   stig          Sterols
# ..            ...    ...              ...
# 746          BDTM   bdtm  Thio Maltosides
# 747         AUDTM  audtm  Thio Maltosides
# 748         BUDTM  budtm  Thio Maltosides
# 749         ADDTM  addtm  Thio Maltosides
# 750         BDDTM  bddtm  Thio Maltosides
#
#                                                   Link
# 0    https://www.charmm-gui.orgarchive/lipid/chl1.t...
# 1    https://www.charmm-gui.orgarchive/lipid/erg.ta...
# 2    https://www.charmm-gui.orgarchive/lipid/dpop.t...
# 3    https://www.charmm-gui.orgarchive/lipid/sito.t...
# 4    https://www.charmm-gui.orgarchive/lipid/stig.t...
# ..                                                 ...
# 746  https://www.charmm-gui.orgarchive/lipid/bdtm.t...
# 747  https://www.charmm-gui.orgarchive/lipid/audtm....
# 748  https://www.charmm-gui.orgarchive/lipid/budtm....
# 749  https://www.charmm-gui.orgarchive/lipid/addtm....
# 750  https://www.charmm-gui.orgarchive/lipid/bddtm....
#
# [751 rows x 4 columns]

# %% [markdown]
# # For https://www.charmm-gui.org/?doc=archive&lib=csml

# %%
def get_formula_res_name_from_pdb_file(link: str) -> tuple(str, str):
    """Fetches a PDB file from a given link, analyzes it to extract the formula and residue name.

    Ressources
    ----------
    https://docs.mdanalysis.org/2.0.0/documentation_pages/topology/guessers.html#guessing-elements-from-atom-names
    https://docs.mdanalysis.org/2.0.0/documentation_pages/topology/guessers.html#MDAnalysis.topology.guessers.guess_atom_type 

    Parameters
    ----------
        link: str
            The URL link to the PDB file.

    Returns
    -------
        tuple(str, str)
            A tuple containing the chemical formula and the name of the residue.
    
    Raises
    ------
        requests.exceptions.HTTPError: If an HTTP error occurs during the request.
        Exception: For other unexpected errors.
    """
    try:
        response = requests.get(link)
        response.raise_for_status()
        filename = link.split("/")[-1]
        open(filename, "wb").write(response.content)

    #In case the given link leads to nothing
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
        return None, None
    except Exception as err:
        print(f"An error occurred: {err}")
        return None, None

    #In case, the file is empty
    if os.path.getsize(filename) == 0:
        return None, None

    molecule = mda.Universe(filename)
    atom_name = []
    res_name = set()

    for atom in molecule.atoms:
        atom_name.append(f"{mda.topology.guessers.guess_atom_type(atom.name)}")
        # print(mda.topology.guessers.guess_atom_element(atom.name))
        res_name.add(atom.resname)

    atom_names = Counter(atom_name)
    sorted_atom_counts = sorted(atom_names.items())
    formula = ''.join(f"{atom}{count}" if count > 1 else atom for atom, count in sorted_atom_counts)

    #To delete the file we just download
    current_dir = Path.cwd()
    absolute_file_path = current_dir / filename
    relative_path = absolute_file_path.relative_to(current_dir)
    relative_path.unlink()

    print(f"File {filename} : {formula} // {res_name}")
    return formula, res_name.pop()

# %%
def parse_lipid_from_charmm_gui2() -> pd.core.frame.DataFrame:
    """Parses lipid information from the CHARMM-GUI website and saves it as a CSV file.

    Returns
    -------
        pd.core.frame.DataFrame
            A DataFrame containing the lipid information with columns:
                - "Name": The name of the lipid.
                - "Alias": The alias of the lipid extracted from the download link.
                - "Category": The category under which the lipid is listed.
                - "Link": The download link for the lipid file.
    """
    url = "https://www.charmm-gui.org/?doc=archive&lib=csml"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    base_url = "https://www.charmm-gui.org/"
    col_names = ["Category", "Alias", "Name", "View_Link", "PDB_Link", "Formula", "Res_name_PDB"]
    recordings = []
        
    rows = soup.find_all("tbody")
    for row in rows:
        category = row.get("id")
        for tr in row.find_all("tr"):
            cells = tr.find_all("td")
            if len(cells) > 1:
                alias = cells[0].text.strip()
                name = cells[1].text.strip()
                view_structure_link = f"https://www.charmm-gui.org/?doc=visualization.ngl.archive&pdb_id={alias.lower()}&arg=csml"
                download_link = base_url + cells[4].find('a')['href'] if cells[4].find('a') else None

                formula, resname_PDB = None, None
                if download_link!=None:
                    formula, resname_PDB = get_formula_res_name_from_pdb_file(download_link)


                recording = {"Category": category, 
                            "Alias": alias, 
                            "Name": name,
                            "View_Link": view_structure_link, 
                            "PDB_Link": download_link, 
                            "Formula": formula, 
                            "Res_name_PDB": resname_PDB}
                recordings.append(recording)
    df = pd.DataFrame(recordings)
    df.to_csv('lipid_CHARMM_GUI2.csv', sep=';', index=False, header=True, columns=col_names)
    return df

# %%
lipid_list2 = parse_lipid_from_charmm_gui2()
lipid_list2 #12min
# Out:
# File alad.pdb : C4CL2H12N2O2 // {'ALA'}
# File aall.pdb : C6H12O6 // {'AAL'}
# File aalt.pdb : C6H12O6 // {'AAL'}
# File aarb.pdb : C5H10O5 // {'AAR'}
# File abeq.pdb : C6H12O4 // {'ABE'}
# File adeo.pdb : C5H10O4 // {'ADE'}
# File afru.pdb : C6H12O6 // {'AFR'}
# File afuc.pdb : C6H12O5 // {'AFU'}
# File agal.pdb : C6H12O6 // {'AGA'}
# File agalna.pdb : C8H15NO6 // {'AGA'}
# File aglc.pdb : C6H12O6 // {'AGL'}
# File aglca.pdb : C6H9O7 // {'AGL'}
# File aglcna.pdb : C8H15NO6 // {'AGL'}
# File agul.pdb : C6H12O6 // {'AGU'}
# File aido.pdb : C6H12O6 // {'AID'}
# File aidoa.pdb : C6H9O7 // {'AID'}
# File allose.pdb : C6H12O6 // {'ALL'}
# File alyf.pdb : C5H10O5 // {'ALY'}
# File aman.pdb : C6H12O6 // {'AMA'}
# File ane5ac.pdb : C11H18NO9 // {'ANE'}
# File arhm.pdb : C6H12O5 // {'ARH'}
# File arhmoa.pdb : C8H14O6 // {'ARH'}
# File arib.pdb : C5H10O5 // {'ARI'}
# File atal.pdb : C6H12O6 // {'ATA'}
# File axyf.pdb : C5H10O5 // {'AXY'}
# File axyl.pdb : C5H10O5 // {'AXY'}
# File ball.pdb : C6H12O6 // {'BAL'}
# File balt.pdb : C6H12O6 // {'BAL'}
# File barb.pdb : C5H10O5 // {'BAR'}
# File bdeo.pdb : C5H10O4 // {'BDE'}
# File bfru.pdb : C6H12O6 // {'BFR'}
# File bfuc.pdb : C6H12O5 // {'BFU'}
# File bgal.pdb : C6H12O6 // {'BGA'}
# File bgalna.pdb : C8H15NO6 // {'BGA'}
# File bglc.pdb : C6H12O6 // {'BGL'}
# File bglca.pdb : C6H9O7 // {'BGL'}
# File bglca0.pdb : C6H9O7 // {'BGL'}
# File bglcn0.pdb : C8H15NO6 // {'BGL'}
# File bglcna.pdb : C8H15NO6 // {'BGL'}
# File bgul.pdb : C6H12O6 // {'BGU'}
# File bido.pdb : C6H12O6 // {'BID'}
# File bidoa.pdb : C6H9O7 // {'BID'}
# File blyf.pdb : C5H10O5 // {'BLY'}
# File bman.pdb : C6H12O6 // {'BMA'}
# File bne5ac.pdb : C11H18NO9 // {'BNE'}
# File brhm.pdb : C6H12O5 // {'BRH'}
# File brib.pdb : C5H10O5 // {'BRI'}
# File btal.pdb : C6H12O6 // {'BTA'}
# File bxyf.pdb : C5H10O5 // {'BXY'}
# File bxyl.pdb : C5H10O5 // {'BXY'}
# File daltol.pdb : C6H14O6 // {'DAL'}
# File daraol.pdb : C5H12O5 // {'DAR'}
# File dgluol.pdb : C6H14O6 // {'DGL'}
# File dgulol.pdb : C6H14O6 // {'DGU'}
# File didiol.pdb : C6H14O6 // {'DID'}
# File dmanol.pdb : C6H14O6 // {'DMA'}
# File dthrol.pdb : C4H10O4 // {'DTH'}
# File ini1.pdb : C6H12O6 // {'INI'}
# File ini2.pdb : C6H12O6 // {'INI'}
# File ini3.pdb : C6H12O6 // {'INI'}
# File ini4.pdb : C6H12O6 // {'INI'}
# File ini5.pdb : C6H12O6 // {'INI'}
# File laltol.pdb : C6H14O6 // {'LAL'}
# File laraol.pdb : C5H12O5 // {'LAR'}
# File lgluol.pdb : C6H14O6 // {'LGL'}
# File lgulol.pdb : C6H14O6 // {'LGU'}
# File lidiol.pdb : C6H14O6 // {'LID'}
# File lmanol.pdb : C6H14O6 // {'LMA'}
# File lthrol.pdb : C4H10O4 // {'LTH'}
# File mallol.pdb : C6H14O6 // {'MAL'}
# File meryol.pdb : C4H10O4 // {'MER'}
# File mgalol.pdb : C6H14O6 // {'MGA'}
# File mglyol.pdb : C3H8O3 // {'MGL'}
# File mribol.pdb : C5H12O5 // {'MRI'}
# File mxylol.pdb : C5H12O5 // {'MXY'}
# File psicos.pdb : C6H12O6 // {'PSI'}
# File dapc.pdb : C48H80NO8P // {'DAP'}
# File dlpa.pdb : C27H52O8P // {'DLP'}
# File dlpc.pdb : C32H64NO8P // {'DLP'}
# File dlpe.pdb : C29H58NO8P // {'DLP'}
# File dlpg.pdb : C30H58O10P // {'DLP'}
# File dlps.pdb : C30H57NO10P // {'DLP'}
# File dmpa.pdb : C31H60O8P // {'DMP'}
# File dmpc.pdb : C36H72NO8P // {'DMP'}
# File dmpe.pdb : C33H66NO8P // {'DMP'}
# File dmpg.pdb : C34H66O10P // {'DMP'}
# File dmps.pdb : C34H65NO10P // {'DMP'}
# File dopa.pdb : C39H72O8P // {'DOP'}
# File dopc.pdb : C44H84NO8P // {'DOP'}
# File dope.pdb : C41H78NO8P // {'DOP'}
# File dopg.pdb : C42H78O10P // {'DOP'}
# File dops.pdb : C42H77NO10P // {'DOP'}
# File dppa.pdb : C35H68O8P // {'DPP'}
# File dppc.pdb : C40H80NO8P // {'DPP'}
# File dppe.pdb : C37H74NO8P // {'DPP'}
# File dppg.pdb : C38H74O10P // {'DPP'}
# File dpps.pdb : C38H73NO10P // {'DPP'}
# File dspa.pdb : C39H76O8P // {'DSP'}
# File dspc.pdb : C44H88NO8P // {'DSP'}
# File dspe.pdb : C41H82NO8P // {'DSP'}
# File dspg.pdb : C42H82O10P // {'DSP'}
# File dsps.pdb : C42H81NO10P // {'DSP'}
# File lppc.pdb : C20H42NO6P // {'LPP'}
# File popa.pdb : C37H70O8P // {'POP'}
# File popc.pdb : C42H82NO8P // {'POP'}
# File pope.pdb : C39H76NO8P // {'POP'}
# File popg.pdb : C40H76O10P // {'POP'}
# File pops.pdb : C40H75NO10P // {'POP'}
# File sapc.pdb : C46H84NO8P // {'SAP'}
# File sdpc.pdb : C48H84NO8P // {'SDP'}
# File sopc.pdb : C44H86NO8P // {'SOP'}
# File 11bpo.pdb : C8H8N2 // {'11B'}
# File 123tbb.pdb : BR3C6H3P3 // {'123'}
# File 123tcb.pdb : C6CL3H3P3 // {'123'}
# File 123tib.pdb : C6H3I3P3 // {'123'}
# File 124tbb.pdb : BR3C6H3P3 // {'124'}
# File 124tcb.pdb : C6CL3H3P3 // {'124'}
# File 124tib.pdb : C6H3I3P3 // {'124'}
# File 12dbb.pdb : BR2C6H4P2 // {'12D'}
# File 12dcb.pdb : C6CL2H4P2 // {'12D'}
# File 12dib.pdb : C6H4I2P2 // {'12D'}
# File 135tbb.pdb : BR3C6H3P3 // {'135'}
# File 135tcb.pdb : C6CL3H3P3 // {'135'}
# File 135tib.pdb : C6H3I3P3 // {'135'}
# File 13bpo.pdb : C8H8N2 // {'13B'}
# File 13dbb.pdb : BR2C6H4P2 // {'13D'}
# File 13dcb.pdb : C6CL2H4P2 // {'13D'}
# File 13dib.pdb : C6H4I2P2 // {'13D'}
# File 14dbb.pdb : BR2C6H4P2 // {'14D'}
# File 14dcb.pdb : C6CL2H4P2 // {'14D'}
# File 14dib.pdb : C6H4I2P2 // {'14D'}
# File 14mn.pdb : C12H12 // {'14M'}
# File 18nfd.pdb : C8H6N2 // {'18N'}
# File 1box.pdb : C4H8O // {'1BO'}
# File 1eox.pdb : C2H4O // {'1EO'}
# File 1mth.pdb : C6H8N2O2 // {'1MT'}
# File 1ph2po.pdb : C11H9NO // {'1PH'}
# File 1ph4po.pdb : C11H9NO // {'1PH'}
# File 21qu.pdb : C9H7NO // {'21Q'}
# File 22bpy.pdb : C10H8N2 // {'22B'}
# File 23mn.pdb : C12H12 // {'23M'}
# File 2amf.pdb : C8H9NO2 // {'2AM'}
# File 2amp.pdb : C7H8N2O // {'2AM'}
# File 2boh.pdb : C4H10O // {'2BO'}
# File 2bty.pdb : C4H6 // {'2BT'}
# File 2dhf.pdb : C4H6O // {'2DH'}
# File 2hpp.pdb : C4H6N // {'2HP'}
# File 2hpr.pdb : C4H5N // {'2HP'}
# File 2imi.pdb : C3H6N2 // {'2IM'}
# File 2imp.pdb : C3H7N2 // {'2IM'}
# File 2mpa.pdb : C8H17N2O // {'2MP'}
# File 2oxt.pdb : C3H4O2 // {'2OX'}
# File 2pdo.pdb : C4H7NO // {'2PD'}
# File 2prl.pdb : C4H7N // {'2PR'}
# File 2prp.pdb : C4H8N // {'2PR'}
# File 2prz.pdb : C3H6N2 // {'2PR'}
# File 2ptz.pdb : C9H7NS // {'2PT'}
# File 2pyo.pdb : C5H5NO // {'2PY'}
# File 2smpyr.pdb : C5H6N2S // {'2SM'}
# File 33bpo.pdb : C8H8N2 // {'33B'}
# File 34ap.pdb : C5H7N3 // {'34A'}
# File 34mp.pdb : C7H9N // {'34M'}
# File 3acp.pdb : C7H7NO // {'3AC'}
# File 3alp.pdb : C6H5NO // {'3AL'}
# File 3amp.pdb : C7H8N2O // {'3AM'}
# File 3apy.pdb : C5H6N2 // {'3AP'}
# File 3bnp.pdb : C12H11N // {'3BN'}
# File 3bpy.pdb : C9H13N // {'3BP'}
# File 3cap.pdb : C6H7NO // {'3CA'}
# File 3cb.pdb : C7H5O2 // {'3CB'}
# File 3cpy.pdb : C6H4NO2 // {'3CP'}
# File 3cyp.pdb : C6H4N2 // {'3CY'}
# File 3etp.pdb : C7H9N // {'3ET'}
# File 3flp.pdb : C5FH4N // {'3FL'}
# File 3hin.pdb : C8H7N // {'3HI'}
# File 3hop.pdb : C5H5NO // {'3HO'}
# File 3hpr.pdb : C4H5N // {'3HP'}
# File 3mep.pdb : C6H7N // {'3ME'}
# File 3nap.pdb : C6H6N2O // {'3NA'}
# File 3oxt.pdb : C3H4O2 // {'3OX'}
# File 3ph24s.pdb : C10H8N2S2 // {'3PH'}
# File 3ph2sr.pdb : C10H8N2OS // {'3PH'}
# File 3ph4sr.pdb : C10H8N2OS // {'3PH'}
# File 3php.pdb : C11H9N // {'3PH'}
# File 3phura.pdb : C10H8N2O2 // {'3PH'}
# File 3prl.pdb : C4H7N // {'3PR'}
# File 3prp.pdb : C4H8N // {'3PR'}
# File 43hpy.pdb : C4H4N2O // {'43H'}
# File 43hspp.pdb : C10H8N2S // {'43H'}
# File 43hspy.pdb : C4H4N2S // {'43H'}
# File 43ppy.pdb : C10H8N2O // {'43P'}
# File 4ap2.pdb : C5H6N2 // {'4AP'}
# File 4cyt.pdb : C8H7N // {'4CY'}
# File 4mep.pdb : C6H7N // {'4ME'}
# File 4o2sm.pdb : C5H6N2OS // {'4O2'}
# File 4pyo.pdb : C5H5NO // {'4PY'}
# File 9mad.pdb : C6H7N5 // {'9MA'}
# File a2fo.pdb : C4H4O2 // {'A2F'}
# File a3ph.pdb : C4H8O6P // {'A3P'}
# File aald.pdb : C2H4O // {'AAL'}
# File aanm.pdb : C4CL2H12N2O2 // {'AAN'}
# File aapm.pdb : C8H14O8P // {'AAP'}
# File abbm.pdb : C8H8NO // {'ABB'}
# File abeb.pdb : C4H8NO // {'ABE'}
# File abmb.pdb : C3H6NO // {'ABM'}
# File abnb.pdb : C8H8NO // {'ABN'}
# File abns.pdb : C5H10O3 // {'ABN'}
# File absb.pdb : C5H5N2OS // {'ABS'}
# File acn.pdb : C2H3N // {'ACN'}
# File aco.pdb : C3H6O // {'ACO'}
# File acrd.pdb : C13H9N // {'ACR'}
# File adam.pdb : C10H16 // {'ADA'}
# /home/karine/miniconda3/envs/kduong-python/lib/python3.11/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: AL
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# File alf4.pdb : ALF4 // {'ALF'}
# File amcp.pdb : C4H10N // {'AMC'}
# File amdn.pdb : C2H7N2 // {'AMD'}
# File amet.pdb : C2H5N // {'AME'}
# File amm1.pdb : H3N // {'AMM'}
# File amol.pdb : C3CAH7O4 // {'AMO'}
# File amop.pdb : C3CAH7O3 // {'AMO'}
# File antr.pdb : C14H10 // {'ANT'}
# File aobt.pdb : C7CSH12N2O2S // {'AOB'}
# File apnh.pdb : C7H12N2O2 // {'APN'}
# File ar3p.pdb : C4H7O6P // {'AR3'}
# File arao.pdb : C4H8O3 // {'ARA'}
# File arim.pdb : C7H10N2O2 // {'ARI'}
# File armo.pdb : C5H10O3 // {'ARM'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/asbb.pdb
# File azdo.pdb : C3H5NO // {'AZD'}
# File azul.pdb : C10H8 // {'AZU'}
# File b2fo.pdb : C4H4O2 // {'B2F'}
# File b5np.pdb : C8H14O5P // {'B5N'}
# File b5sp.pdb : C8H14O5P // {'B5S'}
# File bab1.pdb : C29H47N2O6 // {'BAB'}
# File bab2.pdb : C29H47N2O6 // {'BAB'}
# File bald.pdb : C7H6O // {'BAL'}
# File bam1.pdb : C13H24 // {'BAM'}
# File bami.pdb : C7H9N2 // {'BAM'}
# File bben.pdb : C10H14 // {'BBE'}
# File bca.pdb : C14H8O4 // {'BCA'}
# File beon.pdb : C4H6O // {'BEO'}
# File beyn.pdb : C4H4 // {'BEY'}
# File bf6.pdb : C16H12O6 // {'BF6'}
# File bf7.pdb : C16H8O6 // {'BF7'}
# File bfl.pdb : C12H10 // {'BFL'}
# File bicb.pdb : BC7H7O2 // {'BIC'}
# File binb.pdb : BC7H6O2 // {'BIN'}
# File bm6a.pdb : C8H11N5 // {'BM6'}
# File bnnb.pdb : BC6H5O2 // {'BNNB'}
# File bnne.pdb : BC2H5O2 // {'BNN'}
# File bonb.pdb : BC6H6O2 // {'BON'}
# File bone.pdb : BC2H6O2 // {'BON'}
# File bonn.pdb : BCH3O2 // {'BON'}
# File borb.pdb : BC6H7O2 // {'BOR'}
# File bore.pdb : BC2H7O2 // {'BOR'}
# File born.pdb : BCH4O2 // {'BOR'}
# File boro.pdb : BCH5O2 // {'BOR'}
# File bpet.pdb : C4H10O8P2 // {'BPE'}
# File bpip.pdb : C12H18N // {'BPI'}
# File bpnp.pdb : C7H12O4P // {'BPN'}
# File bpsp.pdb : C7H12O4P // {'BPS'}
# File bret.pdb : BRC2H5 // {'BRE'}
# File brob.pdb : BRC6H5 // {'BRO'}
# File bsam.pdb : C6H7NO2S // {'BSA'}
# File bsat.pdb : C6H5O3S // {'BSA'}
# File btmc.pdb : C7H11N3O // {'BTM'}
# File bton.pdb : C4H8O // {'BTO'}
# File buty.pdb : C4H6 // {'BUT'}
# File c36.pdb : C16H12O7 // {'C36'}
# File c37.pdb : C16H8O7 // {'C37'}
# File c3c.pdb : C14H8O5 // {'C3C'}
# File ca.pdb : C24H39O5 // {'CA'}
# File cald.pdb : C2CLH3O // {'CAL'}
# File cbhh.pdb : C4H6N4O2 // {'CBH'}
# File cbu.pdb : C4H8 // {'CBU'}
# File cdca.pdb : C24H39O4 // {'CDC'}
# File chlb.pdb : C6CLH5P // {'CHL'}
# File chon.pdb : C6H10O // {'CHO'}
# File chxe.pdb : C6H10 // {'CHX'}
# File cinl.pdb : C8H6N2 // {'CIN'}
# File clet.pdb : C2CLH5 // {'CLE'}
# File clm1.pdb : C11H18O // {'CLM'}
# File clns.pdb : C20H32O // {'CLN'}
# File clol.pdb : C27H46O // {'CLO'}
# File cnad.pdb : C11H13N5 // {'CNA'}
# File cncy.pdb : C10H13N3O // {'CNC'}
# File cngu.pdb : C11H13N5O // {'CNG'}
# File cnt1.pdb : C11H14N2O2 // {'CNT'}
# File cnt2.pdb : C11H14N2O2 // {'CNT'}
# File cnt3.pdb : C11H14N2O2 // {'CNT'}
# File cnth.pdb : C11H14N2O2 // {'CNT'}
# File co31.pdb : CHO3 // {'CO3'}
# File cpde.pdb : C5H6 // {'CPD'}
# File cpen.pdb : C5H10 // {'CPE'}
# File cpes.pdb : C5H10 // {'CPE'}
# File crbz.pdb : C12H9N // {'CRB'}
# File csad.pdb : C11H13N5 // {'CSA'}
# File cscy.pdb : C10H13N3O // {'CSC'}
# File csgu.pdb : C11H13N5O // {'CSG'}
# File csth.pdb : C11H14N2O2 // {'CST'}
# File cume.pdb : C9H12 // {'CUM'}
# File cyin.pdb : C9H6N2 // {'CYI'}
# File cype.pdb : C5H8 // {'CYP'}
# File dbre.pdb : BR2C2H4 // {'DBR'}
# File dca.pdb : C24H39O4 // {'DCA'}
# File dcle.pdb : C2CL2H4 // {'DCL'}
# File deca.pdb : C5H10O3 // {'DEC'}
# File decb.pdb : C5H11NO2 // {'DEC'}
# File dete.pdb : C4H10O // {'DET'}
# File dfb.pdb : C6F2H4 // {'DFB'}
# File dft.pdb : C7F2H6 // {'DFT'}
# File dh3t.pdb : C4H8N2S // {'DH3'}
# File diol.pdb : C3H6O2 // {'DIO'}
# File diox.pdb : C4H8O2 // {'DIO'}
# File dith.pdb : C4H8S2 // {'DIT'}
# File dixb.pdb : C4H8O2 // {'DIX'}
# File dma.pdb : C4H9NO // {'DMA'}
# File dmam.pdb : C2H7N // {'DMA'}
# File dman.pdb : C8H11N // {'DMA'}
# File dmbu.pdb : C6H14O2 // {'DMB'}
# File dmca.pdb : C3H6O3 // {'DMC'}
# File dmcb.pdb : C3H7NO2 // {'DMC'}
# File dme.pdb : C4H10O2 // {'DME'}
# File dmee.pdb : C2H6O // {'DME'}
# File dmep.pdb : C2H6O4P // {'DME'}
# File dmf.pdb : C3H7NO // {'DMF'}
# File dmop.pdb : C5H12O2 // {'DMO'}
# File dmpr.pdb : C5H11NO // {'DMP'}
# File dmsn.pdb : C2H6O2S // {'DMS'}
# File dmso.pdb : C2H6OS // {'DMS'}
# File dmtf.pdb : C6H12O // {'DMT'}
# File dmtt.pdb : C3H6S3 // {'DMT'}
# File eepi.pdb : C5H11N // {'EEP'}
# File eesm.pdb : C4H11NO2S // {'EES'}
# File epre.pdb : C5H12O // {'EPR'}
# File esna.pdb : C2H5O3S // {'ESN'}
# File etea.pdb : C3H6N4 // {'ETEA'}
# File etob.pdb : C8H10O // {'ETO'}
# File etrz.pdb : C4H7N3 // {'ETR'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/fad.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/fadr.pdb
# File fbib.pdb : C12H15O3 // {'FBI'}
# File fenz.pdb : C12H8N2 // {'FEN'}
# File feoz.pdb : C12H9NO // {'FEO'}
# File fetz.pdb : C12H9NS // {'FET'}
# File flmo.pdb : C13H12N4O2 // {'FLM'}
# File flmr.pdb : C13H14N4O2 // {'FLM'}
# File flrn.pdb : C13H10 // {'FLR'}
# File flub.pdb : C6FH5 // {'FLU'}
# File flvo.pdb : C14H14N4O2 // {'FLV'}
# File flvr.pdb : C14H16N4O2 // {'FLVR'}
# File fmno.pdb : C17H19N4O9P // {'FMN'}
# File fmnr.pdb : C17H21N4O9P // {'FMN'}
# File fora.pdb : CHO2 // {'FOR'}
# File forh.pdb : CH2O2 // {'FOR'}
# File ftaz.pdb : C8H6N2 // {'FTA'}
# File fura.pdb : C4H4O // {'FUR'}
# File ga.pdb : C29H45NO7 // {'GA'}
# File gabd.pdb : C35H51N2O6 // {'GAB'}
# File gbl.pdb : C4H6O2 // {'GBL'}
# File gtgn.pdb : C10H16N5O13P3S // {'GTG'}
# File gtns.pdb : C10H15N5O12P3S2 // {'GTN'}
# File gtpg.pdb : C10H12N5O13P3S // {'GTP'}
# File gtss.pdb : C10H12N5O12P3S2 // {'GTS'}
# File hdz1.pdb : C4H8N2O // {'HDZ'}
# File hdz1b.pdb : C9H10N2O // {'HDZ'}
# File hdz2.pdb : C16H13N3O2 // {'HDZ'}
# File hdzn.pdb : H4N2 // {'HDZ'}
# File hex3.pdb : C6H8 // {'HEX'}
# File hexd.pdb : C6H14O2 // {'HEX'}
# File hpty.pdb : C7H12 // {'HPT'}
# File hxe2.pdb : C6H12 // {'HXE'}
# File hxyn.pdb : C6H10 // {'HXY'}
# File imdp.pdb : C3H9N2 // {'IMD'}
# File inca.pdb : C10H15N3O // {'INC'}
# File inda.pdb : C7H6N2 // {'IND'}
# File inde.pdb : C9H8 // {'IND'}
# File indi.pdb : C8H9N // {'IND'}
# File indz.pdb : C8H7N // {'IND'}
# File iodb.pdb : C6H5IP // {'IOD'}
# File ipaa.pdb : C4CLH11NO // {'IPA'}
# File iqin.pdb : C9H7N // {'IQI'}
# File isoi.pdb : C8H7N // {'ISO'}
# File isot.pdb : C3H3NS // {'ISO'}
# File isox.pdb : C3H3NO // {'ISO'}
# File lca.pdb : C24H39O3 // {'LCA'}
# File mam1.pdb : CH5N // {'MAM'}
# File mboa.pdb : C8H8O2 // {'MBO'}
# File mbsm.pdb : C7H9NO2S // {'MBS'}
# File mbue.pdb : C5H12O // {'MBU'}
# File mcpe.pdb : C6H12 // {'MCP'}
# File meob.pdb : C7H8O // {'MEO'}
# File meoi.pdb : C9H7NO // {'MEO'}
# File mesi.pdb : C3H10N2O2S // {'MES'}
# File mesn.pdb : C3H8O2S // {'MES'}
# File meso.pdb : C3H8OS // {'MES'}
# File mete.pdb : C3H8O // {'MET'}
# File metp.pdb : CH3O10P3 // {'MET'}
# File mhyo.pdb : C4H4N2O2 // {'MHY'}
# File micy.pdb : C2H3NO // {'MIC'}
# File mind.pdb : C9H9N // {'MIN'}
# File mmsm.pdb : C2H7NO2S // {'MMS'}
# File mmst.pdb : C2H6O3S // {'MMS'}
# File mobu.pdb : C5H8O // {'MOB'}
# File moet.pdb : C3H6O // {'MOE'}
# File morp.pdb : C4H10NO // {'MOR'}
# File mpre.pdb : C4H10O // {'MPR'}
# File mp_0.pdb : CH5O4P // {'MP_'}
# File mrdn.pdb : C4H3NOS2 // {'MRD'}
# File msam.pdb : CH5NO2S // {'MSA'}
# File msch.pdb : C14H17NO // {'MSC'}
# File msmt.pdb : CH5NO3S // {'MSM'}
# File msna.pdb : CH3O3S // {'MSN'}
# File mt2a.pdb : C4H10N2S // {'MT2'}
# File mtdo.pdb : C4H3NO2S // {'MTD'}
# File mtea.pdb : C2H4N4 // {'MTE'}
# File mxyl.pdb : C8H10 // {'MXY'}
# File nact.pdb : C4H8NO4S // {'NAC'}
# File nade.pdb : C11H15N5O6P // {'NAD'}
# File naft.pdb : C10H8 // {'NAF'}
# File nc2.pdb : C2H8N // {'NC2'}
# File nc3.pdb : C3H10N // {'NC3'}
# File neop.pdb : C5H12 // {'NEO'}
# File nesm.pdb : C2H6NO3S // {'NES'}
# File nh4.pdb : H4N // {'NH4'}
# File nime.pdb : CH3NO2 // {'NIM'}
# File nipr.pdb : C3H7NO2 // {'NIP'}
# File nitb.pdb : C6H5NO2 // {'NIT'}
# File nmsm.pdb : CH4NO3S // {'NMS'}
# File norb.pdb : C7H12 // {'NOR'}
# File nthy.pdb : C11H16N2O8P // {'NTH'}
# File nusa.pdb : C10H13N5O3 // {'NUS'}
# File nusc.pdb : C9H13N3O4 // {'NUS'}
# File nusg.pdb : C10H13N5O4 // {'NUS'}
# File nust.pdb : C10H14N2O5 // {'NUS'}
# File nusu.pdb : C9H12N2O5 // {'NUS'}
# File nzad.pdb : C9H11NO // {'NZA'}
# File obtz.pdb : C7H8N2O2S // {'OBT'}
# File octy.pdb : C8H14 // {'OCT'}
# File oihy.pdb : C11H7N3O3 // {'OIH'}
# File oird.pdb : C11H6N2O2S2 // {'OIR'}
# File oxad.pdb : C2H2N2O // {'OXA'}
# File oxaz.pdb : C3H3NO // {'OXA'}
# File oxd4.pdb : C2H2N2O // {'OXD'}
# File oxtn.pdb : C3H6O // {'OXT'}
# File oxyl.pdb : C8H10 // {'OXY'}
# File pald.pdb : C3H6O // {'PAL'}
# File pbsm.pdb : C12H11NO2S // {'PBS'}
# File pclt.pdb : C7CLH7P // {'PCL'}
# File pcro.pdb : C7H8O // {'PCR'}
# File pha.pdb : C2H7NO3P // {'PHA'}
# File phek.pdb : C9H10O // {'PHE'}
# File phhz.pdb : C6H8N2 // {'PHH'}
# File phmk.pdb : C8H8O // {'PHM'}
# File pip.pdb : C5H12N // {'PIP'}
# File pip1.pdb : C6H13NNA // {'PIP'}
# File pip2.pdb : C6H13NNA // {'PIP'}
# File pip3.pdb : C6H13NNAO // {'PIP'}
# File pipa.pdb : C8H7N3 // {'PIP'}
# File piub.pdb : C11H10N // {'PIU'}
# File piuf.pdb : C11FH9N // {'PIU'}
# File pium.pdb : C5H6N // {'PIU'}
# File pmha.pdb : C25CLH20N3O2P // {'PMH'}
# File pmsm.pdb : C7H9NO2S // {'PMS'}
# File pmst.pdb : C7H8O3S // {'PMS'}
# File pnh2.pdb : C5H11N2O // {'PNH'}
# File pnpo.pdb : C6H5NO3 // {'PNP'}
# File pntm.pdb : C19H26N4O2 // {'PNT'}
# File pnty.pdb : C5H8 // {'PNT'}
# File pram.pdb : C3H7NO // {'PRA'}
# File prf.pdb : C7H10N5O // {'PRF'}
# File prld.pdb : C4H9N // {'PRL'}
# File prlp.pdb : C4H10N // {'PRL'}
# File proh.pdb : C3H8O // {'PRO'}
# File prpy.pdb : C3H4 // {'PRP'}
# File prsh.pdb : C3H8S // {'PRS'}
# File przp.pdb : C3H9N2 // {'PRZ'}
# File pscu.pdb : C9H12 // {'PSC'}
# File psmt.pdb : C6H7NO3S // {'PSM'}
# File psna.pdb : C3H7O3S // {'PSN'}
# File ptid.pdb : C6H4N4 // {'PTI'}
# File pur7.pdb : C5H4N4 // {'PUR'}
# File pur9.pdb : C5H4N4 // {'PUR'}
# File pxyl.pdb : C8H10 // {'PXY'}
# File py01.pdb : C5H6O // {'PY0'}
# File py02.pdb : C5H6O // {'PY0'}
# File pyo2b.pdb : C11H9NO // {'PYO'}
# File pyo2f.pdb : C11FH8NO // {'PYO'}
# File pyo3b.pdb : C11H9NO // {'PYO'}
# File pyo3f.pdb : C11FH8NO // {'PYO'}
# File pyr1.pdb : C5H5N // {'PYR'}
# File pyrd.pdb : C4H4N2 // {'PYR'}
# File pyrf.pdb : C10FH8N2 // {'PYR'}
# File pyrh.pdb : C4H5N2 // {'PYR'}
# File pyrl.pdb : C4H5N // {'PYR'}
# File pyrm.pdb : C4H4N2 // {'PYR'}
# File pyrz.pdb : C3H4N2 // {'PYR'}
# File pyzn.pdb : C4H4N2 // {'PYZ'}
# File qinl.pdb : C9H7N // {'QIN'}
# File qinu.pdb : C7H14N // {'QIN'}
# File qinx.pdb : C8H6N2 // {'QIN'}
# File qinz.pdb : C8H6N2 // {'QIN'}
# File r3ph.pdb : C4H8O6P // {'R3P'}
# File rfvo.pdb : C17H20N4O6 // {'RFV'}
# File rfvr.pdb : C17H22N4O6 // {'RFVR'}
# File ribo.pdb : C4H8O3 // {'RIB'}
# File rin.pdb : C9H6O2 // {'RIN'}
# File rm3p.pdb : C5H9O5P // {'RM3'}
# File rnua.pdb : C10H13N5O4 // {'RNU'}
# File rnuc.pdb : C9H13N3O5 // {'RNU'}
# File rnug.pdb : C10H13N5O5 // {'RNU'}
# File rsrf.pdb : C6H10O3 // {'RSR'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm001.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm002.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm003.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm004.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm005.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm006.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm007.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm008.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm009.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm010.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm011.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm012.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm013.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm015.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm016.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm017.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm018.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm019.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm020.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm021.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm022.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm024.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm025.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm026.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm027.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm028.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm029.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm030.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm031.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm033.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm034.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm036.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm037.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm038.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm039.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm040.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm041.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm042.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm043.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm044.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm045.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm046.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm047.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm048.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm049.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm050.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm051.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm052.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm053.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm054.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm055.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm057.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm058.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm059.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm060.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm061.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm062.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm063.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm064.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm065.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm066.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm067.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm068.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm069.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm072.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm073.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm074.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm075.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm077.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm079.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm080.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm081.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm082.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm083.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm084.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm085.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm086.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm087.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm088.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm089.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm090.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm091.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm092.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm093.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm094.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm096.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm097.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm098.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm099.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm100.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm101.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm102.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm103.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm104.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm105.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm106.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm107.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm108.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm109.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm110.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm111.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm112.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm113.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm116.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm117.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm118.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm121.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm122.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm123.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm124.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm125.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm126.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm127.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm128.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm129.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm130.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm131.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm132.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm133.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm134.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm135.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm137.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm139.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm141.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm142.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm143.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm144.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm145.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm146.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm147.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm148.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm149.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm150.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm151.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm152.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm153.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm156.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm157.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm158.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm159.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm160.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm161.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm162.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm163.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm164.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm165.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm166.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm167.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm168.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm169.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm170.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm171.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm172.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm173.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm174.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm175.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm176.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm177.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm178.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm179.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm180.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm181.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm182.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm183.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm184.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm185.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm186.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm187.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm188.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm189.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm193.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm194.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm196.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm197.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm198.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm199.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm200.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm201.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm202.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm203.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm204.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm205.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm207.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm208.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm211.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm212.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm213.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm214.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm215.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm216.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm217.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm218.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm219.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm220.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm221.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm224.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm225.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm227.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm233.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm234.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm237.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm238.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm239.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm240.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm241.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/sm242.pdb
# File styr.pdb : C8H8 // {'STY'}
# File t2fd.pdb : C4FH6O5P // {'T2F'}
# File t2fu.pdb : C4FH6O5P // {'T2F'}
# File t3ph.pdb : C4H8O5P // {'T3P'}
# File t3pm.pdb : C5H10O5P // {'T3P'}
# File t5ph.pdb : C5H10O5P // {'T5P'}
# File tade.pdb : C9H11N5O // {'TAD'}
# File tboh.pdb : C4H10O // {'TBO'}
# File tbre.pdb : BR3C2H3 // {'TBR'}
# File tc243c.pdb : C8H6N2O // {'TC2'}
# File tcle.pdb : C2CL3H3 // {'TCL'}
# File tcyt.pdb : C8H11N3O2 // {'TCY'}
# File teaz.pdb : CH2N4 // {'TEA'}
# File tgua.pdb : C9H11N5O2 // {'TGU'}
# File th3p.pdb : C4H7O5P // {'TH3'}
# File th5h.pdb : C5H10O2 // {'TH5'}
# File th5p.pdb : C5H9O5P // {'TH5'}
# File thaz.pdb : C3H3NS // {'THA'}
# File thf.pdb : C4H8O // {'THF'}
# File thf2.pdb : C5H10O2 // {'THF'}
# File thfc.pdb : C5H10O2 // {'THF'}
# File thfm.pdb : C5H10O // {'THF'}
# File thfo.pdb : C4H8O2 // {'THF'}
# File thip.pdb : C4H4S // {'THI'}
# File thni.pdb : C8H13N3O2 // {'THN'}
# File thnp.pdb : C9H15N3O5P // {'THN'}
# File thp.pdb : C5H10O // {'THP'}
# File thps.pdb : C5H10S // {'THP'}
# File tica.pdb : C10H14N2O // {'TIC'}
# File tm3p.pdb : C5H9O5P // {'TM3'}
# File tmam.pdb : C3H9N // {'TMA'}
# File tmao.pdb : C3H9NO // {'TMA'}
# File tmaop.pdb : C3H10NO // {'TMA'}
# File tmfd.pdb : C5FH8O5P // {'TMF'}
# File tmfu.pdb : C5FH8O5P // {'TMF'}
# File tmor.pdb : C4H10NS // {'TMO'}
# File tmpm.pdb : C6H12O5P // {'TMP'}
# File tolu.pdb : C7H8 // {'TOL'}
# File tphc.pdb : C5H11NO4P // {'TPH'}
# File tria.pdb : C3H3N3 // {'TRI'}
# File trib.pdb : C3H3N3 // {'TRI'}
# File trit.pdb : C3H6S3 // {'TRI'}
# File trz2.pdb : C2H3N3 // {'TRZ'}
# File trz3.pdb : C2H3N3 // {'TRZ'}
# File trz4.pdb : C2H3N3 // {'TRZ'}
# File tspd.pdb : C9H13NO2S2 // {'TSP'}
# File tthy.pdb : C9H12N2O3 // {'TTH'}
# File tura.pdb : C8H10N2O3 // {'TUR'}
# File udca.pdb : C24H39O4 // {'UDC'}
# File ura24s.pdb : C4H4N2S2 // {'URA'}
# File ura2s.pdb : C4H4N2OS // {'URA'}
# File ura4s.pdb : C4H4N2OS // {'URA'}
# File urac.pdb : C4H4N2O2 // {'URA'}
# File urea.pdb : CH4N2O // {'URE'}
# File wei1.pdb : C20H20N4O3S // {'WEI'}
# File wei2.pdb : C15H17N3O3S // {'WEI'}
# File wei3.pdb : C19H20N2O3S // {'WEI'}
# File yt2s.pdb : C8H6N2OS // {'YT2'}
# File yt4s.pdb : C8H6N2OS // {'YT4'}
# File ythy.pdb : C8H6N2O2 // {'YTH'}
# File yts2.pdb : C8H6N2S2 // {'YTS'}
# File zdol.pdb : C7H6O2 // {'ZDO'}
# File zfur.pdb : C8H6O // {'ZFU'}
# File zimi.pdb : C7H6N2 // {'ZIM'}
# File zoic.pdb : C7H6O2 // {'ZOI'}
# File zthp.pdb : C8H6S // {'ZTH'}
# File zthz.pdb : C7H5NS // {'ZTH'}
# File h2po4.pdb : H2O4P // {'H2PO'}
# File h2so4.pdb : H2O4S // {'H2SO'}
# File h3po4.pdb : H3O4P // {'H3PO'}
# File hpo4.pdb : HO4P // {'HPO4'}
# File hso4.pdb : HO4S // {'HSO4'}
# File po4.pdb : O4P // {'PO4'}
# File so4.pdb : O4S // {'SO4'}
# File eamt.pdb : C2H7N // {'EAM'}
# File eamti.pdb : C2H8N // {'EAM'}
# File thdlk.pdb : C2H6S // {'THD'}
# File thslk.pdb : CH4S // {'THS'}
# File tmaet.pdb : C5H14N // {'TMA'}
# File 13bdc.pdb : C4H8 // {'13B'}
# File 13bdt.pdb : C4H8 // {'13B'}
# File 14ipc.pdb : C5H10 // {'14I'}
# File 14ipt.pdb : C5H10 // {'14I'}
# File 1butr.pdb : C4H10 // {'1BU'}
# File 1buts.pdb : C4H10 // {'1BU'}
# File aacir.pdb : C3H5O2 // {'AAC'}
# File aacis.pdb : C3H5O2 // {'AAC'}
# File aacr.pdb : C3H6O2 // {'AAC'}
# File aacs.pdb : C3H6O2 // {'AAC'}
# File aamdr.pdb : C3H7NO // {'AAM'}
# File aamds.pdb : C3H7NO // {'AAM'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/aamir.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/aamis.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/aamr.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/aams.pdb
# File acnr.pdb : C3H5N // {'ACN'}
# File acns.pdb : C3H5N // {'ACN'}
# File amidi.pdb : C2H5NO // {'AMI'}
# File amidu.pdb : C2H5NO // {'AMI'}
# File dmitc.pdb : C6H10O4 // {'DMI'}
# File eimin.pdb : C2H7N // {'EIM'}
# File eimini.pdb : C2H7N // {'EIM'}
# File ethox.pdb : C2H6O // {'ETH'}
# File ethoxi.pdb : C2H6O // {'ETH'}
# File ethy.pdb : C2H6 // {'ETH'}
# File etktr.pdb : C4H8O // {'ETK'}
# File etkts.pdb : C4H8O // {'ETK'}
# File hdbtr.pdb : C4H8O2 // {'HDB'}
# File hdbts.pdb : C4H8O2 // {'HDB'}
# File ketn.pdb : C3H6O // {'KET'}
# File ketni.pdb : C3H6O // {'KET'}
# File lactr.pdb : C3H6O2 // {'LAC'}
# File lacts.pdb : C3H6O2 // {'LAC'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/maair.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/maais.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/maar.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/maas.pdb
# File macr.pdb : C4H8O2 // {'MAC'}
# File macs.pdb : C4H8O2 // {'MAC'}
# File mmar.pdb : C5H10O2 // {'MMAR'}
# File mmas.pdb : C5H10O2 // {'MMA'}
# File nipamr.pdb : C6H13NO // {'NIP'}
# File nipams.pdb : C6H13NO // {'NIP'}
# File nsbar.pdb : C7H15NO // {'NSB'}
# File nsbas.pdb : C7H15NO // {'NSB'}
# File ntbar.pdb : C4H9NO // {'NTB'}
# File ntbas.pdb : C4H9NO // {'NTB'}
# File nyl3.pdb : C3H7NO // {'NYL'}
# File nyl6.pdb : C6H13NO // {'NYL'}
# File pacr.pdb : C6H12O2 // {'PAC'}
# File pacs.pdb : C6H12O2 // {'PAC'}
# File pefa.pdb : C8H8O5 // {'PEF'}
# File petl.pdb : C10H10O4 // {'PET'}
# File pibut.pdb : C4H10 // {'PIB'}
# File pmar.pdb : C7H14O2 // {'PMA'}
# File pmas.pdb : C7H14O2 // {'PMA'}
# File pror.pdb : C3H8 // {'PRO'}
# File pros.pdb : C3H8 // {'PROS'}
# File proxir.pdb : C3H8O // {'PRO'}
# File proxis.pdb : C3H8O // {'PRO'}
# File proxr.pdb : C3H8O // {'PRO'}
# File proxs.pdb : C3H8O // {'PRO'}
# File styrr.pdb : C8H10 // {'STY'}
# File styrs.pdb : C8H10 // {'STY'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/tefet.pdb
# File vialr.pdb : C2H6O // {'VIA'}
# File vials.pdb : C2H6O // {'VIA'}
# File vicr.pdb : C2CLH5 // {'VIC'}
# File vics.pdb : C2CLH5 // {'VIC'}
# File vifr.pdb : C2FH5 // {'VIF'}
# File vifs.pdb : C2FH5 // {'VIF'}
# File vipr.pdb : C6H11NO // {'VIP'}
# File vips.pdb : C6H11NO // {'VIP'}
# File actn.pdb : C2H3N // {'ACT'}
# File acto.pdb : C3H6O // {'ACT'}
# File cyhe.pdb : C6H12 // {'CYH'}
# File dibpl.pdb : C16H22O4 // {'DIB'}
# File hexs.pdb : C6H14 // {'HEX'}
# File octn.pdb : C8H18 // {'OCT'}
# File octo.pdb : C8H18O // {'OCT'}
# File ppol.pdb : C4H10O // {'PPO'}
# File tcbs.pdb : C6CL3H3 // {'TCB'}
# File bar.pdb : B // {'BAR'}
# File cal.pdb : CA // {'CAL'}
# File cd2.pdb : C // {'CD2'}
# File ces.pdb : CS // {'CES'}
# File cla.pdb : CL // {'CLA'}
# File h2o2.pdb : H2O2 // {'H2O2'}
# /home/karine/miniconda3/envs/kduong-python/lib/python3.11/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: LI
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# File lit.pdb : LI // {'LIT'}
# File mg.pdb : MG // {'MG'}
# File oh.pdb : HO // {'OH'}
# File pot.pdb : K // {'POT'}
# /home/karine/miniconda3/envs/kduong-python/lib/python3.11/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: R
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# File rub.pdb : R // {'RUB'}
# File sod.pdb : NA // {'SOD'}
# File tip3.pdb : H2O // {'TIP3'}
# ...
# File step.pdb : C18H36O2 // {'STE'}
# File tha.pdb : C24H35O2 // {'THA'}
# File thap.pdb : C24H36O2 // {'THA'}
# File thchl.pdb : C32H56OS // {'THC'}
# File thdppc.pdb : C41H82NO8PS // {'THD'}
# File tpa.pdb : C24H37O2 // {'TPA'}
# File tpap.pdb : C24H38O2 // {'TPA'}
# File tpt.pdb : C24H37O2 // {'TPT'}
# File tptp.pdb : C24H38O2 // {'TPT'}
# File tri.pdb : C23H45O2 // {'TRI'}
# File trip.pdb : C23H46O2 // {'TRI'}
# File tripao.pdb : C22H38N2O2 // {'TRI'}
# File trpaop.pdb : C22H39N2O2 // {'TRP'}
# File tta.pdb : C24H39O2 // {'TTA'}
# File ttap.pdb : C24H40O2 // {'TTA'}
# File udao.pdb : C13H29NO // {'UDA'}
# File udaop.pdb : C13H30NO // {'UDA'}
# File ufos10.pdb : C16H34NO4P // {'UFO'}
# File dhpce.pdb : C40H84NO6P // {'DHP'}
# File dmpce.pdb : C36H76NO6P // {'DMP'}
# File dmpee.pdb : C33H70NO6P // {'DMP'}
# File dopce.pdb : C44H88NO6P // {'DOP'}
# File dopee.pdb : C41H82NO6P // {'DOP'}
# File dppee.pdb : C37H78NO6P // {'DPP'}
# File pla18.pdb : C41H80NO7P // {'PLA'}
# File pla20.pdb : C43H78NO7P // {'PLA'}
# File plc18.pdb : C44H86NO7P // {'PLC'}
# File plc20.pdb : C46H84NO7P // {'PLC'}
# File plc22.pdb : C48H84NO7P // {'PLC'}
# File popce.pdb : C42H86NO6P // {'POP'}
# File popee.pdb : C39H80NO6P // {'POP'}
# File a2udm.pdb : C23H42O11 // {'A2U'}
# File abac.pdb : C10H18N2O5 // {'ABA'}
# File acy3g.pdb : C15H28O6 // {'ACY'}
# File acy3m.pdb : C21H38O11 // {'ACY'}
# File acy4m.pdb : C22H40O11 // {'ACY'}
# File acy5m.pdb : C23H42O11 // {'ACY'}
# File acy6m.pdb : C24H44O11 // {'ACY'}
# File acy7m.pdb : C25H46O11 // {'ACY'}
# File addg.pdb : C18H36O6 // {'ADD'}
# File addm.pdb : C24H46O11 // {'ADD'}
# File addtm.pdb : C24H46O10S // {'ADD'}
# File adg.pdb : C16H32O6 // {'ADG'}
# File adm.pdb : C22H42O11 // {'ADM'}
# File admhm.pdb : C21H40O11 // {'ADM'}
# File adtm.pdb : C22H42O10S // {'ADT'}
# File ahtg.pdb : C13H26O5S // {'AHT'}
# File amhcg.pdb : C15H29NO7 // {'AMH'}
# File ang.pdb : C15H30O6 // {'ANG'}
# File anm.pdb : C21H40O11 // {'ANM'}
# File antm.pdb : C21H40O10S // {'ANT'}
# File aog.pdb : C14H28O6 // {'AOG'}
# File aom.pdb : C20H38O11 // {'AOM'}
# File aotg.pdb : C14H28O5S // {'AOT'}
# File aotm.pdb : C20H38O10S // {'AOT'}
# File appm.pdb : C20H38O11 // {'APP'}
# File atm.pdb : C25H48O11 // {'ATM'}
# File audm.pdb : C23H44O11 // {'AUD'}
# File audtm.pdb : C23H44O10S // {'AUD'}
# File b2udm.pdb : C23H42O11 // {'B2U'}
# File bbac.pdb : C10H18N2O5 // {'BBA'}
# File bbcyg.pdb : C32H59NO13 // {'BBC'}
# File bbphg.pdb : C32H53NO13 // {'BBP'}
# File bcy3g.pdb : C15H28O6 // {'BCY'}
# File bcy3m.pdb : C21H38O11 // {'BCY'}
# File bcy4m.pdb : C22H40O11 // {'BCY'}
# File bcy5m.pdb : C23H42O11 // {'BCY'}
# File bcy6m.pdb : C24H44O11 // {'BCY'}
# File bcy7m.pdb : C25H46O11 // {'BCY'}
# File bddg.pdb : C18H36O6 // {'BDD'}
# File bddm.pdb : C24H46O11 // {'BDD'}
# File bddtm.pdb : C24H46O10S // {'BDD'}
# File bdg.pdb : C16H32O6 // {'BDG'}
# File bdm.pdb : C22H42O11 // {'BDM'}
# File bdmhm.pdb : C21H40O11 // {'BDM'}
# File bdmng.pdb : C43H80O22 // {'BDM'}
# File bdtm.pdb : C22H42O10S // {'BDT'}
# File bhtg.pdb : C13H26O5S // {'BHT'}
# File blmng.pdb : C47H88O22 // {'BLM'}
# File bmhcg.pdb : C15H29NO7 // {'BMH'}
# File bng.pdb : C15H30O6 // {'BNG'}
# File bnm.pdb : C21H40O11 // {'BNM'}
# File bntm.pdb : C21H40O10S // {'BNT'}
# File bog.pdb : C14H28O6 // {'BOG'}
# File bogng.pdb : C27H52O12 // {'BOG'}
# File boing.pdb : C27H52O12 // {'BOI'}
# File bom.pdb : C20H38O11 // {'BOM'}
# File botg.pdb : C14H28O5S // {'BOT'}
# File botgng.pdb : C27H52O10S2 // {'BOT'}
# File botm.pdb : C20H38O10S // {'BOT'}
# File bppm.pdb : C20H38O11 // {'BPP'}
# File btm.pdb : C25H48O11 // {'BTM'}
# File budm.pdb : C23H44O11 // {'BUD'}
# File budtm.pdb : C23H44O10S // {'BUD'}
# File c10eg5.pdb : C20H42O6 // {'C10'}
# File c10eg6.pdb : C22H46O7 // {'C10'}
# File c10eg9.pdb : C28H58O10 // {'C10'}
# File c12deg.pdb : C32H66O11 // {'C12'}
# File c12eg7.pdb : C26H54O8 // {'C12'}
# File c12eg8.pdb : C28H58O9 // {'C12'}
# File c12eg9.pdb : C30H62O10 // {'C12'}
# File c13eg8.pdb : C29H60O9 // {'C13'}
# File c5mng.pdb : C45H80O22 // {'C5M'}
# File c6eg3.pdb : C12H26O4 // {'C6E'}
# File c6eg4.pdb : C14H30O5 // {'C6E'}
# File c6eg5.pdb : C16H34O6 // {'C6E'}
# File c6mng.pdb : C47H84O22 // {'C6M'}
# File c7eg4.pdb : C15H32O5 // {'C7E'}
# File c7eg5.pdb : C17H36O6 // {'C7E'}
# File c8eg4.pdb : C16H34O5 // {'C8E'}
# File c8eg5.pdb : C18H38O6 // {'C8E'}
# File c8eg6.pdb : C20H42O7 // {'C8E'}
# File dheg.pdb : C18H37NO7 // {'DHE'}
# File dl16pp.pdb : C80H132O7P2 // {'DL1'}
# File dl19pp.pdb : C95H156O7P2 // {'DL1'}
# File dmg.pdb : C17H35NO6 // {'DMG'}
# File egtm10.pdb : C81H152O39 // {'EGT'}
# File egtm11.pdb : C84H158O39 // {'EGT'}
# File mgtm10.pdb : C83H156O41 // {'MGT'}
# File mgtm11.pdb : C86H162O41 // {'MGT'}
# File nheg.pdb : C17H35NO7 // {'NHE'}
# File nidp40.pdb : C32H58O10 // {'NID'}
# File nmg.pdb : C16H33NO6 // {'NMG'}
# File smdd.pdb : C24H44O12 // {'SMD'}
# File tx100.pdb : C34H62O11 // {'TX1'}
# File tx114.pdb : C30H54O9 // {'TX1'}
# File tx305.pdb : C74H142O31 // {'TX3'}
# File tx405.pdb : C94H182O41 // {'TX4'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/tzme10.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/tzme9.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/tzmh10.pdb
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/tzmh9.pdb
# File undpp.pdb : C55H90O7P2 // {'UND'}
# File a6hep.pdb : C7H14O6 // {'A6H'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/a6tal.pdb
# File a8leg.pdb : C13H21N2O8 // {'A8L'}
# File aalla.pdb : C6H9O7 // {'AAL'}
# File aalln.pdb : C6H14NO5 // {'AAL'}
# File aallna.pdb : C8H15NO6 // {'AAL'}
# File aalta.pdb : C6H9O7 // {'AAL'}
# File aaltn.pdb : C6H14NO5 // {'AAL'}
# File aaltna.pdb : C8H15NO6 // {'AAL'}
# File aarbp.pdb : C5H10O5 // {'AAR'}
# File aasc.pdb : C6H12O4 // {'AAS'}
# File acol.pdb : C6H12O4 // {'ACO'}
# File adarbp.pdb : C5H10O5 // {'ADA'}
# File adfuc.pdb : C6H12O5 // {'ADF'}
# File adfucf.pdb : C6H12O5 // {'ADF'}
# File adha.pdb : C7H8O8 // {'ADH'}
# File adhep.pdb : C7H14O7 // {'ADH'}
# File adig.pdb : C6H12O4 // {'ADI'}
# File adpsi.pdb : C6H12O6 // {'ADP'}
# File adrhm.pdb : C6H12O5 // {'ADR'}
# File afrup.pdb : C6H12O6 // {'AFR'}
# File afucna.pdb : C8H15NO5 // {'AFU'}
# File agala.pdb : C6H9O7 // {'AGA'}
# File agalaa.pdb : C9H19N2O6 // {'AGA'}
# File agalf.pdb : C6H12O6 // {'AGA'}
# File agaln.pdb : C6H14NO5 // {'AGA'}
# File aglaa.pdb : C8H12NO7 // {'AGL'}
# File aglcn.pdb : C6H14NO5 // {'AGL'}
# File agula.pdb : C6H9O7 // {'AGU'}
# File aguln.pdb : C6H14NO5 // {'AGU'}
# File agulna.pdb : C8H15NO6 // {'AGU'}
# File ahep.pdb : C7H14O7 // {'AHE'}
# File aidon.pdb : C6H14NO5 // {'AID'}
# File aidona.pdb : C8H15NO6 // {'AID'}
# File akda.pdb : C11H17O8 // {'AKD'}
# File akdn.pdb : C9H15O9 // {'AKD'}
# File akdo.pdb : C8H13O8 // {'AKD'}
# File ako.pdb : C8H13O9 // {'AKO'}
# File al6alt.pdb : C6H12O5 // {'AL6'}
# File al6tal.pdb : C6H12O5 // {'AL6'}
# File alall.pdb : C6H12O6 // {'ALA'}
# File alalna.pdb : C8H15NO6 // {'ALA'}
# File alalt.pdb : C6H12O6 // {'ALA'}
# File alalta.pdb : C6H9O7 // {'ALA'}
# File alarb.pdb : C5H10O5 // {'ALA'}
# File aleg.pdb : C13H21N2O8 // {'ALE'}
# File alfru.pdb : C6H12O6 // {'ALF'}
# File algal.pdb : C6H12O6 // {'ALG'}
# File algalf.pdb : C6H12O6 // {'ALG'}
# File algana.pdb : C8H15NO6 // {'ALG'}
# File alglaa.pdb : C8H12NO7 // {'ALG'}
# File alglc.pdb : C6H12O6 // {'ALG'}
# File alglna.pdb : C8H15NO6 // {'ALG'}
# File algul.pdb : C6H12O6 // {'ALG'}
# File algula.pdb : C6H9O7 // {'ALG'}
# File alguna.pdb : C8H15NO6 // {'ALG'}
# File alidna.pdb : C8H15NO6 // {'ALI'}
# File alido.pdb : C6H12O6 // {'ALI'}
# File alman.pdb : C6H12O6 // {'ALM'}
# File almana.pdb : C8H15NO6 // {'ALM'}
# File alqui.pdb : C6H12O5 // {'ALQ'}
# File alrib.pdb : C5H10O5 // {'ALR'}
# File alribp.pdb : C5H10O5 // {'ALR'}
# File alrulf.pdb : C5H10O5 // {'ALR'}
# File altagp.pdb : C6H12O6 // {'ALT'}
# File altal.pdb : C6H12O6 // {'ALT'}
# File altana.pdb : C8H15NO6 // {'ALT'}
# File alxyl.pdb : C5H10O5 // {'ALX'}
# File alyxp.pdb : C5H10O5 // {'ALY'}
# File amana.pdb : C6H9O7 // {'AMA'}
# File amann.pdb : C6H14NO5 // {'AMA'}
# File amanna.pdb : C8H15NO6 // {'AMA'}
# File amu2ac.pdb : C11H18NO8 // {'AMU'}
# File amu2gc.pdb : C11H18NO9 // {'AMU'}
# File amur.pdb : C9H16NO7 // {'AMU'}
# File ane5gc.pdb : C11H18NO10 // {'ANE'}
# File aneu.pdb : C9H16NO8 // {'ANE'}
# File aoli.pdb : C6H12O4 // {'AOL'}
# File apar.pdb : C6H12O4 // {'APA'}
# File apse.pdb : C13H21N2O8 // {'APS'}
# File apsi.pdb : C6H12O6 // {'APS'}
# File apsip.pdb : C6H12O6 // {'APS'}
# File aqui.pdb : C6H12O5 // {'AQU'}
# File aquina.pdb : C8H15NO5 // {'AQU'}
# File arhmna.pdb : C8H15NO5 // {'ARH'}
# File aribp.pdb : C5H10O5 // {'ARI'}
# File asor.pdb : C6H12O6 // {'ASO'}
# File asorp.pdb : C6H12O6 // {'ASO'}
# File atag.pdb : C6H12O6 // {'ATA'}
# File atagp.pdb : C6H12O6 // {'ATA'}
# File atala.pdb : C6H9O7 // {'ATA'}
# File ataln.pdb : C6H14NO5 // {'ATA'}
# File atalna.pdb : C8H15NO6 // {'ATA'}
# File atyv.pdb : C6H12O4 // {'ATY'}
# File axulf.pdb : C5H10O5 // {'AXU'}
# File b6hep.pdb : C7H14O6 // {'B6H'}
# HTTP error occurred: 404 Client Error: Not Found for url: https://www.charmm-gui.org/archive/csml/b6tal.pdb
# File b8leg.pdb : C13H21N2O8 // {'B8L'}
# File balla.pdb : C6H9O7 // {'BAL'}
# File balln.pdb : C6H14NO5 // {'BAL'}
# File ballna.pdb : C8H15NO6 // {'BAL'}
# File balta.pdb : C6H9O7 // {'BAL'}
# File baltn.pdb : C6H14NO5 // {'BAL'}
# File baltna.pdb : C8H15NO6 // {'BAL'}
# File barbp.pdb : C5H10O5 // {'BAR'}
# File basc.pdb : C6H12O4 // {'BAS'}
# File bcol.pdb : C6H12O4 // {'BCO'}
# File bdarbp.pdb : C5H10O5 // {'BDA'}
# File bdfuc.pdb : C6H12O5 // {'BDF'}
# File bdfucf.pdb : C6H12O5 // {'BDF'}
# File bdha.pdb : C7H8O8 // {'BDH'}
# File bdhep.pdb : C7H14O7 // {'BDH'}
# File bdig.pdb : C6H12O4 // {'BDI'}
# File bdpsi.pdb : C6H12O6 // {'BDP'}
# File bdrhm.pdb : C6H12O5 // {'BDR'}
# File bfrup.pdb : C6H12O6 // {'BFR'}
# File bfucna.pdb : C8H15NO5 // {'BFU'}
# File bgala.pdb : C6H9O7 // {'BGA'}
# File bgalf.pdb : C6H12O6 // {'BGA'}
# File bgaln.pdb : C6H13NO5 // {'BGA'}
# File bglcn.pdb : C6H14NO5 // {'BGL'}
# File bglgl.pdb : C8H12NO8 // {'BGL'}
# File bgula.pdb : C6H9O7 // {'BGU'}
# File bguln.pdb : C6H14NO5 // {'BGU'}
# File bgulna.pdb : C8H15NO6 // {'BGU'}
# File bhep.pdb : C7H14O7 // {'BHE'}
# File bidon.pdb : C6H14NO5 // {'BID'}
# File bidona.pdb : C8H15NO6 // {'BID'}
# File bkdn.pdb : C9H15O9 // {'BKD'}
# File bko.pdb : C8H13O9 // {'BKO'}
# File bl6alt.pdb : C6H12O5 // {'BL6'}
# File bl6tal.pdb : C6H12O5 // {'BL6'}
# File blall.pdb : C6H12O6 // {'BLA'}
# File blalna.pdb : C8H15NO6 // {'BLA'}
# File blalt.pdb : C6H12O6 // {'BLA'}
# File blalta.pdb : C6H9O7 // {'BLA'}
# File blarb.pdb : C5H10O5 // {'BLA'}
# File bleg.pdb : C13H21N2O8 // {'BLE'}
# File blfru.pdb : C6H12O6 // {'BLF'}
# File blgal.pdb : C6H12O6 // {'BLG'}
# File blgalf.pdb : C6H12O6 // {'BLG'}
# File blgana.pdb : C8H15NO6 // {'BLG'}
# File blglc.pdb : C6H12O6 // {'BLG'}
# File blglna.pdb : C8H15NO6 // {'BLG'}
# File blgul.pdb : C6H12O6 // {'BLG'}
# File blgula.pdb : C6H9O7 // {'BLG'}
# File blguna.pdb : C8H15NO6 // {'BLG'}
# File blidna.pdb : C8H15NO6 // {'BLI'}
# File blido.pdb : C6H12O6 // {'BLI'}
# File blman.pdb : C6H12O6 // {'BLM'}
# File blmana.pdb : C8H15NO6 // {'BLM'}
# File blqui.pdb : C6H12O5 // {'BLQ'}
# File blrib.pdb : C5H10O5 // {'BLR'}
# File blribp.pdb : C5H10O5 // {'BLR'}
# File blrulf.pdb : C5H10O5 // {'BLR'}
# File bltagp.pdb : C6H12O6 // {'BLT'}
# File bltal.pdb : C6H12O6 // {'BLT'}
# File bltana.pdb : C8H15NO6 // {'BLT'}
# File blxyl.pdb : C5H10O5 // {'BLX'}
# File blyxp.pdb : C5H10O5 // {'BLY'}
# File bmana.pdb : C6H9O7 // {'BMA'}
# File bmann.pdb : C6H14NO5 // {'BMA'}
# File bmanna.pdb : C8H15NO6 // {'BMA'}
# File bmu2ac.pdb : C11H18NO8 // {'BMU'}
# File bmu2gc.pdb : C11H18NO9 // {'BMU'}
# File bmur.pdb : C9H16NO7 // {'BMU'}
# File bne5gc.pdb : C11H18NO10 // {'BNE'}
# File bneu.pdb : C9H16NO8 // {'BNE'}
# File boli.pdb : C6H12O4 // {'BOL'}
# File bpar.pdb : C6H12O4 // {'BPA'}
# File bpse.pdb : C13H21N2O8 // {'BPS'}
# File bpsi.pdb : C6H12O6 // {'BPS'}
# File bpsip.pdb : C6H12O6 // {'BPS'}
# File bqui.pdb : C6H12O5 // {'BQU'}
# File bquina.pdb : C8H15NO5 // {'BQU'}
# File brhmna.pdb : C8H15NO5 // {'BRH'}
# File bribp.pdb : C5H10O5 // {'BRI'}
# File bsor.pdb : C6H12O6 // {'BSO'}
# File bsorp.pdb : C6H12O6 // {'BSO'}
# File btag.pdb : C6H12O6 // {'BTA'}
# File btagp.pdb : C6H12O6 // {'BTA'}
# File btala.pdb : C6H9O7 // {'BTA'}
# File btaln.pdb : C6H14NO5 // {'BTA'}
# File btalna.pdb : C8H15NO6 // {'BTA'}
# File btyv.pdb : C6H12O4 // {'BTY'}
# File bxulf.pdb : C5H10O5 // {'BXU'}
# File dglya.pdb : C3H5O4 // {'DGL'}
# File dphg.pdb : C43H88O3 // {'DPH'}
# File etpp.pdb : C2H7NO7P2 // {'ETP'}
# File quita.pdb : C10H19NO6 // {'QUI'}
# File r1.pdb : C10H18NOS2 // {'R1'}
# File r5.pdb : C10H20NOS2 // {'R5'}
# File r5u.pdb : C10H20NOS2 // {'R5U'}
# File lti.pdb : L // {'LTI'}
# /home/karine/miniconda3/envs/kduong-python/lib/python3.11/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: L
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
#                                       Category Alias  \
# 0                     top_all36_prot.rtf_tbody   ALA
# 1                     top_all36_prot.rtf_tbody  ALAD
# 2                     top_all36_prot.rtf_tbody   ARG
# 3                     top_all36_prot.rtf_tbody   ASN
# 4                     top_all36_prot.rtf_tbody   ASP
# ...                                        ...   ...
# 2164         toppar_all36_label_spin.str_tbody    R5
# 2165         toppar_all36_label_spin.str_tbody   R5U
# 2166         toppar_all36_label_spin.str_tbody   SLH
# 2167         toppar_all36_label_spin.str_tbody   SLT
# 2168  toppar_all36_label_fluorophore.str_tbody   LTI
#
#                                                   Name  \
# 0                                              alanine
# 1                                    alanine dipeptide
# 2                                             arginine
# 3                                           asparagine
# 4                                        aspartic acid
# ...                                                ...
# 2164         SPIN LABEL FOR PROTEINS CHI2POT = 0.04066
# 2165         SPIN LABEL FOR PROTEINS CHI2POT = 0.04066
# 2166  SPIN LABEL FOR LIPID HEADGROUP CHI2POT = 0.04202
# 2167      SPIN LABEL FOR LIPID TAILS CHI2POT = 0.04376
# 2168                          LANTHANIDE ION, HUAN RUI
#
#                                               View_Link  \
# 0     https://www.charmm-gui.org/?doc=visualization....
# 1     https://www.charmm-gui.org/?doc=visualization....
# 2     https://www.charmm-gui.org/?doc=visualization....
# 3     https://www.charmm-gui.org/?doc=visualization....
# 4     https://www.charmm-gui.org/?doc=visualization....
# ...                                                 ...
# 2164  https://www.charmm-gui.org/?doc=visualization....
# 2165  https://www.charmm-gui.org/?doc=visualization....
# 2166  https://www.charmm-gui.org/?doc=visualization....
# 2167  https://www.charmm-gui.org/?doc=visualization....
# 2168  https://www.charmm-gui.org/?doc=visualization....
#
#                                               PDB_Link       Formula  \
# 0                                                 None          None
# 1     https://www.charmm-gui.org/archive/csml/alad.pdb  C4CL2H12N2O2
# 2                                                 None          None
# 3                                                 None          None
# 4                                                 None          None
# ...                                                ...           ...
# 2164    https://www.charmm-gui.org/archive/csml/r5.pdb    C10H20NOS2
# 2165   https://www.charmm-gui.org/archive/csml/r5u.pdb    C10H20NOS2
# 2166   https://www.charmm-gui.org/archive/csml/slh.pdb          None
# 2167   https://www.charmm-gui.org/archive/csml/slt.pdb          None
# 2168   https://www.charmm-gui.org/archive/csml/lti.pdb             L
#
#      Res_name_PDB
# 0            None
# 1           {ALA}
# 2            None
# 3            None
# 4            None
# ...           ...
# 2164         {R5}
# 2165        {R5U}
# 2166         None
# 2167         None
# 2168        {LTI}
#
# [2169 rows x 7 columns]
